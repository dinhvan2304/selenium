# %%
import pandas as pd
import re

input_HO = pd.read_excel("/Users/dinhvan/Documents/Projects/Crawl/selenium/SOE/SOE_input1.xlsx",dtype = {'MST': str})

def no_accent_vietnamese(s):
    s = re.sub(r'[àáạảãâầấậẩẫăằắặẳẵ]', 'a', s)
    s = re.sub(r'[ÀÁẠẢÃĂẰẮẶẲẴÂẦẤẬẨẪ]', 'A', s)
    s = re.sub(r'[èéẹẻẽêềếệểễ]', 'e', s)
    s = re.sub(r'[ÈÉẸẺẼÊỀẾỆỂỄ]', 'E', s)
    s = re.sub(r'[òóọỏõôồốộổỗơờớợởỡ]', 'o', s)
    s = re.sub(r'[ÒÓỌỎÕÔỒỐỘỔỖƠỜỚỢỞỠ]', 'O', s)
    s = re.sub(r'[ìíịỉĩ]', 'i', s)
    s = re.sub(r'[ÌÍỊỈĨ]', 'I', s)
    s = re.sub(r'[ùúụủũưừứựửữ]', 'u', s)
    s = re.sub(r'[ƯỪỨỰỬỮÙÚỤỦŨ]', 'U', s)
    s = re.sub(r'[ỳýỵỷỹ]', 'y', s)
    s = re.sub(r'[ỲÝỴỶỸ]', 'Y', s)
    s = re.sub(r'[Đ]', 'D', s)
    s = re.sub(r'[đ]', 'd', s)
    return s


list1 = []
for i in input_HO['Địa chỉ HO']:
    list1.append(no_accent_vietnamese(i))
    
input_HO['address_solved'] = pd.Series(list1)
input_HO['address_solved'] = input_HO['address_solved'].str.lower()
input_HO['address_solved'] = input_HO['address_solved'].str.replace(' ','')
# input_HO

list_temp = []
for i in input_HO['address_solved']:
    if 'hochiminh' in i or 'hcm' in i:
        list_temp.append('TP Hồ Chí Minh')
        continue
    elif 'hanoi' in i:
        list_temp.append('Hà Nội')
        continue
    elif 'thanhhoa' in i:
        list_temp.append('Thanh Hoá')
        continue
    elif 'hungyen' in i:
        list_temp.append('Hưng Yên')
        continue
    elif 'angiang' in i:
        list_temp.append('An Giang')
        continue
    elif 'vungtau' in i:
        list_temp.append('Bà Rịa - Vũng Tàu')
        continue
    elif 'bacgiang' in i:
        list_temp.append('Bắc Giang')
        continue
    elif 'thaibinh' in i:
        list_temp.append('Thái Bình')
        continue
    elif 'thainguyen' in i:
        list_temp.append('Thái Nguyên')
        continue
    elif 'backan' in i:
        list_temp.append('Bắc Kạn')
        continue
    elif 'baclieu' in i:
        list_temp.append('Bạc Liêu')
        continue
    elif 'bacninh' in i:
        list_temp.append('Bắc Ninh')
        continue
    elif 'bentre' in i:
        list_temp.append('Bến Tre')
        continue
    elif 'binhdinh' in i:
        list_temp.append('Bình Định')
        continue
    elif 'binhduong' in i:
        list_temp.append('Bình Dương')
        continue
    elif 'binhphuoc' in i:
        list_temp.append('Bình Phước')
        continue
    elif 'binhthuan' in i:
        list_temp.append('Bình Thuận')
        continue
    elif 'camau' in i:
        list_temp.append('Cà Mau')
        continue
    elif 'cantho' in i:
        list_temp.append('Cần Thơ')
        continue
    elif 'caobang' in i:
        list_temp.append('Cao Bằng')
        continue
    elif 'danang' in i:
        list_temp.append('Đà Nẵng')
        continue
    elif 'daklak' in i:
        list_temp.append('Đắk Lắk')
        continue
    elif 'daknong' in i:
        list_temp.append('Đắk Nông')
        continue
    elif 'dienbien' in i:
        list_temp.append('Điện Biên')
        continue
    elif 'dongnai' in i:
        list_temp.append('Đồng Nai')
        continue
    elif 'dongthap' in i:
        list_temp.append('Đồng Tháp')
        continue
    elif 'gialai' in i:
        list_temp.append('Gia Lai')
        continue
    elif 'hagiang' in i:
        list_temp.append('Hà Giang')
        continue
    elif 'hanam' in i:
        list_temp.append('Hà Nam')
        continue
    elif 'hatinh' in i:
        list_temp.append('Hà Tĩnh')
        continue
    elif 'haiduong' in i:
        list_temp.append('Hải Dương')
        continue
    elif 'haiphong' in i:
        list_temp.append('Hải Phòng')
        continue
    elif 'haugiang' in i:
        list_temp.append('Hậu Giang')
        continue
    elif 'hoabinh' in i:
        list_temp.append('Hòa Bình')
        continue
    elif 'khanhhoa' in i:
        list_temp.append('Khánh Hòa')
        continue
    elif 'kiengiang' in i:
        list_temp.append('Kiên Giang')
        continue
    elif 'kontum' in i:
        list_temp.append('Kon Tum')
        continue
    elif 'laichau' in i:
        list_temp.append('Lai Châu')
        continue
    elif 'lamdong' in i:
        list_temp.append('Lâm Đồng')
        continue
    elif 'langson' in i:
        list_temp.append('Lạng Sơn')
        continue
    elif 'laocai' in i:
        list_temp.append('Lào Cai')
        continue
    elif 'longan' in i:
        list_temp.append('Long An')
        continue
    elif 'namdinh' in i:
        list_temp.append('Nam Định')
        continue
    elif 'nghean' in i:
        list_temp.append('Nghệ An')
        continue
    elif 'ninhbinh' in i:
        list_temp.append('Ninh Bình')
        continue
    elif 'ninhthuan' in i:
        list_temp.append('Ninh Thuận')
        continue
    elif 'phutho' in i:
        list_temp.append('Phú Thọ')
        continue
    elif 'phuyen' in i:
        list_temp.append('Phú Yên')
        continue
    elif 'quangbinh' in i:
        list_temp.append('Quảng Bình')
        continue
    elif 'quangnam' in i:
        list_temp.append('Quảng Nam')
        continue
    elif 'quangngai' in i:
        list_temp.append('Quảng Ngãi')
        continue
    elif 'quangninh' in i:
        list_temp.append('Quảng Ninh')
        continue
    elif 'quangtri' in i:
        list_temp.append('Quảng Trị')
        continue
    elif 'soctrang' in i:
        list_temp.append('Sóc Trăng')
        continue
    elif 'sonla' in i:
        list_temp.append('Sơn La')
        continue
    elif 'tayninh' in i:
        list_temp.append('Tây Ninh')
        continue
    elif 'thuathien' in i:
        list_temp.append('Thừa Thiên Huế')
        continue
    elif 'tiengiang' in i:
        list_temp.append('Tiền Giang')
        continue
    elif 'travinh' in i:
        list_temp.append('Trà Vinh')
        continue
    elif 'tuyenquang' in i:
        list_temp.append('Tuyên Quang')
        continue
    elif 'vinhlong' in i:
        list_temp.append('Vĩnh Long')
        continue
    elif 'vinhphuc' in i:
        list_temp.append('Vĩnh Phúc')
        continue
    elif 'yenbai' in i:
        list_temp.append('Yên Bái')
        continue
    else:
        list_temp.append('Khong xac dinh')
        
input_HO['TTP'] = pd.Series(list_temp)
input_HO = input_HO.drop(columns=['address_solved'],axis = 1)
input_HO

# %%
import pandas as pd

result = pd.read_csv("/Users/dinhvan/Documents/Projects/Crawl/selenium/SOE/result/SOE2/Result_search_CTC.csv",dtype={'mst':str})
result_solved = result[result['name_result'].str.contains("Nhiều hơn")]
result_solved.to_csv("/Users/dinhvan/Documents/Projects/Crawl/selenium/SOE/result/SOE2/Nhieu_ket_qua.csv", index = False)
