# %%
import pandas as pd
import numpy

# %%
data = pd.read_csv("/Users/dinhvan/Projects/Code/crawl/selenium/nha_thuoc/a_chau.csv", dtype = str)
data = data.drop_duplicates(keep= "first", ignore_index= True)
data.to_csv("/Users/dinhvan/Projects/Code/crawl/selenium/nha_thuoc/a_chau.csv", index = False)

# %%
data.loc[data['dien_thoai'].isna()]
# Out:
#                                                Nha_thuoc  \
# 3                                     Nhà thuốc Vân Ngọc
# 6                  NT Thanh Nhàn - DS: Phan Thị Thu Hằng
# 11                  Nhà thuốc Anh Tuấn - DS Trần Thị Thử
# 19                                        NT Asia Pharco
# 53                                       NT Phương Khanh
# 59                         NT 832 - DS Đỗ Thị Quỳnh Sang
# 228    Công ty CP dược phẩm An Khang Pharma (Kho An K...
# 496                                 Quầy thuốc Châu Ngọc
# 1591                                          QT Bảo Tín
# 1592                                        QT Bích Hồng
# 1979               NT Thanh Nhàn - DS: Phan Thị Thu Hằng
# 1984                       NT Thu Huyền - DS:Vũ Thị Thủy
# 2185                 NT Pharmart - DS: Trần Thị Thu Hằng
# 2186               NT Phương Đông - DS : Trần Lan Phương
# 2401                      NT Tuệ Tâm - DS Đinh Tuấn Hiệp
# ...
