# %%
import pandas as pd
import numpy as np
data1  = pd.read_csv('/Users/dinhvan/Documents/Projects/Crawl/selenium/vnr500/VNR500/vnr_500_16_11.csv',dtype={'MST':np.str})
data2  = pd.read_csv('/Users/dinhvan/Documents/Projects/Crawl/selenium/vnr500/VNR500/vnr_500.csv',dtype={'Mã số thuế': np.str})
# data3 = data1.loc[data1['doanh_thu_2021'].isna() == False]
# data4 = data2.loc[data2['Mã chứng khoán'] != 'Chưa niêm yết']
# d2 = dict(zip(data3['MST'],data3['doanh_thu_2021']))
# data4['doanh_thu_2021'] = data4['Mã số thuế'].map(d2)
# data4.to_csv('check_doanh_thu.csv',index = False)
data2 = data2.drop(['Xếp hạng VNR500','Trụ sở chính','Tel','Fax','E-mail','Website'],axis=1)
dict_company = dict(zip(data1['MST'],data1['Company']))
dict_CEO = dict(zip(data1['MST'],data1['CEO']))
dict_NN = dict(zip(data1['MST'],data1['NGANH_NGHE']))
dict_2020 = dict(zip(data1['MST'],data1['doanh_thu_2020']))
dict_2021 = dict(zip(data1['MST'],data1['doanh_thu_2021']))
dict_tinh = dict(zip(data1['MST'],data1['tinh']))

data2['Ten cong ty'] = data2['Mã số thuế'].map(dict_company)
data2['CEO'] = data2['Mã số thuế'].map(dict_CEO)
data2['Nganh nghe'] = data2['Mã số thuế'].map(dict_NN)
data2['Doanh thu 2020'] = data2['Mã số thuế'].map(dict_2020)
data2['Doanh thu 2021'] = data2['Mã số thuế'].map(dict_2021)
data2['Tinh'] = data2['Mã số thuế'].map(dict_tinh)
data3 = data2.loc[data2['Mã chứng khoán'] != 'Chưa niêm yết']
data3 = data3.loc[data3['Doanh thu 2021'].isna() == True]
data3
# Out:
# /var/folders/x7/psmldpq556b7kvl0wpx_bx_h0000gn/T/ipykernel_38111/3907024367.py:3: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data1  = pd.read_csv('/Users/dinhvan/Documents/Projects/Crawl/selenium/vnr500/VNR500/vnr_500_16_11.csv',dtype={'MST':np.str})
# /var/folders/x7/psmldpq556b7kvl0wpx_bx_h0000gn/T/ipykernel_38111/3907024367.py:4: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# ...
